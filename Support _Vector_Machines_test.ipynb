# %%
import math
import statistics
import numpy as np
import pandas as pd

# %%
#13

#6x1 + 8x2 - 48 = 0

w1, w2, b = 6, 8, -48
norm = math.sqrt(w1 ** 2 + w2 ** 2)

#a
print("a:")
sp = w1 * 10 + w2 * 2 + b
sq = w1 * 3 + w2 * 3 + b
print("||w||:", norm)
print("p score:", sp)
print("q score:", sq)
print("***************************************")

#b
print("b:")
print("p distance:", abs(sp) / norm)
print("q distance:", abs(sq) / norm)

#c q is closer (0.6 < 2.8), so q is probably
#going to be the support vector
# Out:
# a:
# ||w||: 10.0
# p score: 28
# q score: -6
# ***************************************
# b:
# p distance: 2.8
# q distance: 0.6
