# %%
import math
import statistics
import numpy as np
import pandas as pd

# %%
#11

#a
#at,au,bt,bu = a tickets, a usege, b tickets, b usege
at = (2 - 0) / (10 - 0)
au = (80 - 0) / (100 - 0)

bt = (9 - 0) / (10 - 0)
bu = (15 - 0) / (100 - 0)

newt = (6 - 0) / (10 - 0)
newu = (40 - 0) / (100 - 0)

print("a scaled:", at, au)
print("b scaled:", bt, bu)
print("new scaled:", newt, newu)


#b
#da and db = distance to a and distance to b
da = math.sqrt((newt - at) ** 2 + (newu - au) ** 2)
db = math.sqrt((newt - bt) ** 2 + (newu - bu) ** 2)

print("distance to a:", round(da, 3))
print("distance to b:", round(db, 3))


#c
#when k = 1 the closest point would be point b 
#(0.391 compered to point a = 0.566 which is further away) witch means 
#that based on the "model" the new costomer is going to cancel the subscription (predicted: yes)
# Out:
# a scaled: 0.2 0.8
# b scaled: 0.9 0.15
# new scaled: 0.6 0.4
# distance to a: 0.566
# distance to b: 0.391

# %%
#12

#the simplest way to avoid a tie altogether is to pick an odd k like 3 or 5
#and run the model again if i must keep k = 4 i can use distance-weighted voting
#each neighbour gets a weight based on its distance (closer point = bigger weight)
#then i add up the weights for each class and the class with the bigger total wins
