# %%
import math
import statistics
import numpy as np
import pandas as pd

# %%
#8

e = 2.718281828
b0 = -3
b1 = 0.6
x = 3

z = b0 + b1 * x
p = 1 / (1 + e ** (-z))

print("z:", round(z, 2))
print("prob of spam:", round(p, 4))
# Out:
# z: -1.2
# Prob of spam: 0.2315

# %%
#9

e = 2.718281828
b0 = -3
b1 = 0.6
x = 8

z = b0 + b1 * x
p = 1 / (1 + e ** (-z))

print("z:", round(z, 2))
print("prob of spam:", round(p, 4))
# Out:
# z: 1.8
# Probability of spam: 0.8581
